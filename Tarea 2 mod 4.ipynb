# %%
pip install python-utils
# Out:
# Collecting python-utils
#   Downloading https://files.pythonhosted.org/packages/eb/a0/19119d8b7c05be49baf6c593f11c432d571b70d805f2fe94c0585e55e4c8/python_utils-2.3.0-py2.py3-none-any.whl
# Requirement already satisfied: six in c:\users\scaballero\anaconda3\lib\site-packages (from python-utils) (1.13.0)
# Installing collected packages: python-utils
# Successfully installed python-utils-2.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
python -m pip install name utils

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.datasets import fetch_california_housing, make_moons
from sklearn.linear_model import Ridge, LinearRegression, LogisticRegression, Lasso
from sklearn.model_selection import GridSearchCV, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error, f1_score
from ipywidgets import interact, FloatSlider
from numpy.random import seed, randn
from sklearn.ensemble import BaggingClassifier

# %%
from sklearn.preprocessing import OneHotEncoder, PolynomialFeatures
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, cross_validate
import utils
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-3cceeda72cad> in <module>
#       4 from sklearn.pipeline import Pipeline
#       5 from sklearn.model_selection import train_test_split, cross_validate
# ----> 6 import utils
#
# ModuleNotFoundError: No module named 'utils'

# %%
from sklearn.cluster import KMaeans
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-59d2a480ec6b> in <module>
# ----> 1 from sklearn.cluster import KMaeans
#
# ImportError: cannot import name 'KMaeans' from 'sklearn.cluster' (C:\Users\SCABALLERO\Anaconda3\lib\site-packages\sklearn\cluster\__init__.py)

# %%
# %config InlineBackend.figure_format = "retina"
plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["font.size"] = 13

# %%
X, y = make_moons(100, noise=0.2, random_state=2718)
X_test, y_test = make_moons(40, noise=0.2, random_state=31415)
plt.scatter(*X.T, c=y, cmap="Set2");

# %%
model = Pipeline([
    ('poly', PolynomialFeatures(degree=30, include_bias=False)),
    ('logistic', LogisticRegression(penalty="none"))
])

bagging_logreg = BaggingClassifier(model, n_estimators=100, random_state=314,
                                  bootstrap=True, max_samples=100, n_jobs=-1)

# %%
bagging_logreg.fit(X, y)
# Out:
# BaggingClassifier(base_estimator=Pipeline(memory=None,
#                                           steps=[('poly',
#                                                   PolynomialFeatures(degree=30,
#                                                                      include_bias=False,
#                                                                      interaction_only=False,
#                                                                      order='C')),
#                                                  ('logistic',
#                                                   LogisticRegression(C=1.0,
#                                                                      class_weight=None,
#                                                                      dual=False,
#                                                                      fit_intercept=True,
#                                                                      intercept_scaling=1,
#                                                                      l1_ratio=None,
#                                                                      max_iter=100,
#                                                                      multi_class='auto',
#                                                                      n_jobs=None,
#                                                                      penalty='none',
#                                                                      random_state=None,
#                                                                      solver='lbfgs',
#                                                                      tol=0.0001,
#                                                                      verbose=0,
#                                                                      warm_start=False))],
#                                           verbose=False),
#                   bootstrap=True, bootstrap_features=False, max_features=1.0,
#                   max_samples=100, n_estimators=100, n_jobs=-1, oob_score=False,
#                   random_state=314, verbose=0, warm_start=False)

# %%
# creo que el problema que tengo con esto es que no tengo el file de utils en el archivo correcto
#fig, ax = plt.subplots(1, 1, figsize=(12, 4))

#utils.plot_classf_model(X, y, bagging_logreg, ax=ax, contour=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-385131e54639> in <module>
#       1 fig, ax = plt.subplots(1, 1, figsize=(12, 4))
#       2
# ----> 3 utils.plot_classf_model(X, y, bagging_logreg, ax=ax, contour=True)
#
# NameError: name 'utils' is not defined

# %%
yhat_test = bagging_logreg.predict(X_test)
f1_score(y_test, yhat_test)
# Out:
# 0.8947368421052632
